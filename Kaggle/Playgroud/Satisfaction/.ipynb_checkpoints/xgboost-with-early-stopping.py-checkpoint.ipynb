# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("Agg") #Needed to save figures
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import roc_auc_score
# Out:
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/scipy/__init__.py:115: UserWarning: Numpy 1.13.3 or above is required for this version of scipy (detected version 1.13.1)
#   UserWarning)

# %%
training = pd.read_csv("/Users/szkfzx/datasets/santander-customer-satisfaction/train.csv", index_col=0)
test = pd.read_csv("/Users/szkfzx/datasets/santander-customer-satisfaction/test.csv", index_col=0)

# %%
training.head()
# Out:
#     var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID
# 1      2     23                 0.0                      0.0
# 3      2     34                 0.0                      0.0
# 4      2     23                 0.0                      0.0
# 8      2     37                 0.0                    195.0
# 10     2     39                 0.0                      0.0
#
#     imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# ID
# 1                       0.0                      0.0                      0.0
# 3                       0.0                      0.0                      0.0
# 4                       0.0                      0.0                      0.0
# 8                     195.0                      0.0                      0.0
# 10                      0.0                      0.0                      0.0
#
#     imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  imp_op_var40_ult1  ...  \
# ID                                                                       ...
# 1                       0.0                      0.0                0.0  ...
# 3                       0.0                      0.0                0.0  ...
# 4                       0.0                      0.0                0.0  ...
# 8                       0.0                      0.0                0.0  ...
# 10                      0.0                      0.0                0.0  ...
#
#     saldo_medio_var33_hace2  saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# ID
# 1                       0.0                      0.0                     0.0
# 3                       0.0                      0.0                     0.0
# 4                       0.0                      0.0                     0.0
# 8                       0.0                      0.0                     0.0
# 10                      0.0                      0.0                     0.0
#
#     saldo_medio_var33_ult3  saldo_medio_var44_hace2  saldo_medio_var44_hace3  \
# ID
# 1                      0.0                      0.0                      0.0
# 3                      0.0                      0.0                      0.0
# 4                      0.0                      0.0                      0.0
# 8                      0.0                      0.0                      0.0
# 10                     0.0                      0.0                      0.0
#
#     saldo_medio_var44_ult1  saldo_medio_var44_ult3          var38  TARGET
# ID
# 1                      0.0                     0.0   39205.170000       0
# 3                      0.0                     0.0   49278.030000       0
# 4                      0.0                     0.0   67333.770000       0
# 8                      0.0                     0.0   64007.970000       0
# 10                     0.0                     0.0  117310.979016       0
#
# [5 rows x 370 columns]

# %%
test.head()
# Out:
#     var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID
# 2      2     32                 0.0                      0.0
# 5      2     35                 0.0                      0.0
# 6      2     23                 0.0                      0.0
# 7      2     24                 0.0                      0.0
# 9      2     23                 0.0                      0.0
#
#     imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  imp_op_var40_comer_ult3  \
# ID
# 2                       0.0                      0.0                      0.0
# 5                       0.0                      0.0                      0.0
# 6                       0.0                      0.0                      0.0
# 7                       0.0                      0.0                      0.0
# 9                       0.0                      0.0                      0.0
#
#     imp_op_var40_efect_ult1  imp_op_var40_efect_ult3  imp_op_var40_ult1  ...  \
# ID                                                                       ...
# 2                       0.0                      0.0                0.0  ...
# 5                       0.0                      0.0                0.0  ...
# 6                       0.0                      0.0                0.0  ...
# 7                       0.0                      0.0                0.0  ...
# 9                       0.0                      0.0                0.0  ...
#
#     saldo_medio_var29_ult3  saldo_medio_var33_hace2  saldo_medio_var33_hace3  \
# ID
# 2                      0.0                      0.0                      0.0
# 5                      0.0                      0.0                      0.0
# 6                      0.0                      0.0                      0.0
# 7                      0.0                      0.0                      0.0
# 9                      0.0                      0.0                      0.0
#
#     saldo_medio_var33_ult1  saldo_medio_var33_ult3  saldo_medio_var44_hace2  \
# ID
# 2                      0.0                     0.0                      0.0
# 5                      0.0                     0.0                      0.0
# 6                      0.0                     0.0                      0.0
# 7                      0.0                     0.0                      0.0
# 9                      0.0                     0.0                      0.0
#
#     saldo_medio_var44_hace3  saldo_medio_var44_ult1  saldo_medio_var44_ult3  \
# ID
# 2                       0.0                     0.0                     0.0
# 5                       0.0                     0.0                     0.0
# 6                       0.0                     0.0                     0.0
# 7                       0.0                     0.0                     0.0
# 9                       0.0                     0.0                     0.0
#
#         var38
# ID
# 2    40532.10
# 5    45486.72
# 6    46993.95
# 7   187898.61
# 9    73649.73
#
# [5 rows x 369 columns]

# %%
print(training.shape)
print(test.shape)
# Out:
# (76020, 370)
# (75818, 369)

# %%
# Replace -999999 in var3 column with most common value 2 
# See https://www.kaggle.com/cast42/santander-customer-satisfaction/debugging-var3-999999
# for details
training = training.replace(-999999,2)

# %%
# Replace 9999999999 with NaN
# See https://www.kaggle.com/c/santander-customer-satisfaction/forums/t/19291/data-dictionary/111360#post111360
# training = training.replace(9999999999, np.nan)
# training.dropna(inplace=True)
# Leads to validation_0-auc:0.839577

X = training.iloc[:,:-1]
y = training.TARGET

# %%
# Add zeros per row as extra feature
X['n0'] = (X == 0).sum(axis=1)
# # Add log of var38
# X['logvar38'] = X['var38'].map(np.log1p)
# # Encode var36 as category
# X['var36'] = X['var36'].astype('category')
# X = pd.get_dummies(X)

# %%
# Add PCA components as features
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

X_normalized = normalize(X, axis=0) #数据集正则化
pca = PCA(n_components=2) #主成分分析，个数为2
X_pca = pca.fit_transform(X_normalized)
X['PCA1'] = X_pca[:,0]
X['PCA2'] = X_pca[:,1]

# %%
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import f_classif,chi2
from sklearn.preprocessing import Binarizer, scale

p = 86 # 308 features validation_1-auc:0.848039
p = 80 # 284 features validation_1-auc:0.848414
p = 77 # 267 features validation_1-auc:0.848000
p = 75 # 261 features validation_1-auc:0.848642
# p = 73 # 257 features validation_1-auc:0.848338
# p = 70 # 259 features validation_1-auc:0.848588
# p = 69 # 238 features validation_1-auc:0.848547
# p = 67 # 247 features validation_1-auc:0.847925
# p = 65 # 240 features validation_1-auc:0.846769
# p = 60 # 222 features validation_1-auc:0.848581

# %%
X_bin = Binarizer().fit_transform(scale(X))
selectChi2 = SelectPercentile(chi2, percentile=p).fit(X_bin, y)
selectF_classif = SelectPercentile(f_classif, percentile=p).fit(X, y)
# Out:
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:172: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:114: UserWarning: Features [ 21  22  56  57  58  59  80  84  85 131 132 133 134 155 161 162 179 180
#  189 192 220 222 234 238 244 248 261 262 303 307 315 319 327 349] are constant.
#   UserWarning)
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
chi2_selected = selectChi2.get_support()
chi2_selected_features = [ f for i,f in enumerate(X.columns) if chi2_selected[i]]
print('Chi2 selected {} features {}.'.format(chi2_selected.sum(),
   chi2_selected_features))
f_classif_selected = selectF_classif.get_support()
f_classif_selected_features = [ f for i,f in enumerate(X.columns) if f_classif_selected[i]]
print('F_classif selected {} features {}.'.format(f_classif_selected.sum(),
   f_classif_selected_features))
selected = chi2_selected & f_classif_selected
print('Chi2 & F_classif selected {} features'.format(selected.sum()))
features = [ f for f,s in zip(X.columns, selected) if s]
print (features)
# Out:
# Chi2 selected 279 features ['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'imp_sal_var16_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var40_ult3', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var35', 'num_var37_med_ult2', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var1', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var17', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_hace3', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_emit_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_in_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_hace3', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3', 'nu ...
# F_classif selected 279 features ['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var6', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13_medio_0', 'num_var13_medio', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var18_0', 'num_var18', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var29', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var34_0', 'num_var34', 'num_var35', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_amort_var18_1y3', 'delta_imp_amort_var34_1y3', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_reemb_var17_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var7_recib_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var1 ...
# Chi2 & F_classif selected 263 features
# ['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var35', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3', 'num_meses_var17_ult3', 'num_meses_var29_ult3', 'num_meses_var33_ult3', 'num_meses_var39_vig_ult3', 'num_meses_var44_ult3', 'num_op_var39_comer_ult1', 'num_op_var40_comer_ult1', 'num_op_var40_comer_ult3', 'num_op_var40_efect_ult1', 'num_op_var40_efec ...

# %%
X_sel = X[features]

X_train, X_test, y_train, y_test = train_test_split(X_sel, y, random_state=1301, stratify=y, test_size=0.4)

# xgboost parameter tuning with p = 75
# recipe: https://www.kaggle.com/c/bnp-paribas-cardif-claims-management/forums/t/19083/best-practices-for-parameter-tuning-on-models/108783#post108783

# %%
ratio = float(np.sum(y == 1)) / np.sum(y==0)
# Initial parameters for the parameter exploration
# clf = xgb.XGBClassifier(missing=9999999999,
#                 max_depth = 10,
#                 n_estimators=1000,
#                 learning_rate=0.1, 
#                 nthread=4,
#                 subsample=1.0,
#                 colsample_bytree=0.5,
#                 min_child_weight = 5,
#                 scale_pos_weight = ratio,
#                 seed=4242)

# %%
# gives : validation_1-auc:0.845644
# max_depth=8 -> validation_1-auc:0.846341
# max_depth=6 -> validation_1-auc:0.845738
# max_depth=7 -> validation_1-auc:0.846504
# subsample=0.8 -> validation_1-auc:0.844440
# subsample=0.9 -> validation_1-auc:0.844746
# subsample=1.0,  min_child_weight=8 -> validation_1-auc:0.843393
# min_child_weight=3 -> validation_1-auc:0.848534
# min_child_weight=1 -> validation_1-auc:0.846311
# min_child_weight=4 -> validation_1-auc:0.847994
# min_child_weight=2 -> validation_1-auc:0.847934
# min_child_weight=3, colsample_bytree=0.3 -> validation_1-auc:0.847498
# colsample_bytree=0.7 -> validation_1-auc:0.846984
# colsample_bytree=0.6 -> validation_1-auc:0.847856
# colsample_bytree=0.5, learning_rate=0.05 -> validation_1-auc:0.847347
# max_depth=8 -> validation_1-auc:0.847352
# learning_rate = 0.07 -> validation_1-auc:0.847432
# learning_rate = 0.2 -> validation_1-auc:0.846444
# learning_rate = 0.15 -> validation_1-auc:0.846889
# learning_rate = 0.09 -> validation_1-auc:0.846680
# learning_rate = 0.1 -> validation_1-auc:0.847432
# max_depth=7 -> validation_1-auc:0.848534
# learning_rate = 0.05 -> validation_1-auc:0.847347
#

# %%
clf = xgb.XGBClassifier(missing=9999999999,
                max_depth = 5,
                n_estimators=1000,
                learning_rate=0.1, 
                nthread=4,
                subsample=1.0,
                colsample_bytree=0.5,
                min_child_weight = 3,
                scale_pos_weight = ratio,
                reg_alpha=0.03,
                seed=1301)
                
clf.fit(X_train, y_train, early_stopping_rounds=50, eval_metric="auc",
        eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 50 rounds.
# [1]	validation_0-auc:0.5	validation_1-auc:0.5
# [2]	validation_0-auc:0.5	validation_1-auc:0.5
# [3]	validation_0-auc:0.5	validation_1-auc:0.5
# [4]	validation_0-auc:0.5	validation_1-auc:0.5
# [5]	validation_0-auc:0.5	validation_1-auc:0.5
# [6]	validation_0-auc:0.5	validation_1-auc:0.5
# [7]	validation_0-auc:0.5	validation_1-auc:0.5
# [8]	validation_0-auc:0.5	validation_1-auc:0.5
# [9]	validation_0-auc:0.5	validation_1-auc:0.5
# [10]	validation_0-auc:0.5	validation_1-auc:0.5
# [11]	validation_0-auc:0.5	validation_1-auc:0.5
# [12]	validation_0-auc:0.5	validation_1-auc:0.5
# [13]	validation_0-auc:0.5	validation_1-auc:0.5
# [14]	validation_0-auc:0.5	validation_1-auc:0.5
# [15]	validation_0-auc:0.5	validation_1-auc:0.5
# [16]	validation_0-auc:0.5	validation_1-auc:0.5
# [17]	validation_0-auc:0.5	validation_1-auc:0.5
# [18]	validation_0-auc:0.5	validation_1-auc:0.5
# [19]	validation_0-auc:0.679193	validation_1-auc:0.682766
# [20]	validation_0-auc:0.712395	validation_1-auc:0.716866
# [21]	validation_0-auc:0.714792	validation_1-auc:0.718974
# [22]	validation_0-auc:0.714793	validation_1-auc:0.718968
# [23]	validation_0-auc:0.71551	validation_1-auc:0.719472
# [24]	validation_0-auc:0.71551	validation_1-auc:0.719472
# [25]	validation_0-auc:0.71513	validation_1-auc:0.718915
# [26]	validation_0-auc:0.717156	validation_1-auc:0.720382
# [27]	validation_0-auc:0.71767	validation_1-auc:0.721341
# [28]	validation_0-auc:0.71768	validation_1-auc:0.721344
# [29]	validation_0-auc:0.717681	validation_1-auc:0.721393
# [30]	validation_0-auc:0.717681	validation_1-auc:0.721393
# [31]	validation_0-auc:0.717681	validation_1-auc:0.721393
# [32]	validation_0-auc:0.726509	validation_1-auc:0.728427
# [33]	validation_0-auc:0.733956	validation_1-auc:0.734904
# [34]	validation_0-auc:0.734725	validation_1-auc:0.735433
# [35]	validation_0-auc:0.734748	validation_1-auc:0.73532
# [36]	validation_0-auc:0.73656	validation_1-auc:0.737562
# [37]	validation_0-auc:0.737116	validation_1-auc:0.737699
# [38]	validation_0-auc:0.7408	validation_1-auc:0.739797
# [39]	validation_0-auc:0.740675	validation_1-auc:0.739544
# [40]	validation_0-auc:0.743593	validation_1-auc:0.741792
# [41]	validation_0-auc:0.79705	validation_1-auc:0.79486
# [42]	validation_0-auc:0.798439	validation_1-auc:0.796268
# [43]	validation_0-auc:0.798446	validation_1-auc:0.795518
# [44]	validation_0-auc:0.804675	validation_1-auc:0.801908
# [45]	validation_0-auc:0.804978	validation_1-auc:0.801719
# [46]	validation_0-auc:0.804998	validation_1-auc:0.801492
# [47]	validation_0-auc:0.808583	validation_1-auc:0.804622
# [48]	validation_0-auc:0.809772	validation_1-auc:0.80618
# [49]	validation_0-auc:0.813634	validation_1-auc:0.809785
# [50]	validation_0-auc:0.81629	validation_1-auc:0.81264
# [51]	validation_0-auc:0.819247	validation_1-auc:0.817334
# [52]	validation_0-auc:0.820931	validation_1-auc:0.819573
# [53]	validation_0-auc:0.82114	validation_1-auc:0.819637
# [54]	validation_0-auc:0.820767	validation_1-auc:0.819106
# [55]	validation_0-auc:0.821104	validation_1-auc:0.818972
# [56]	validation_0-auc:0.82435	validation_1-auc:0.822316
# [57]	validation_0-auc:0.82601	validation_1-auc:0.824105
# [58]	validation_0-auc:0.827899	validation_1-auc:0.825814
# [59]	validation_0-auc:0.828569	validation_1-auc:0.827273
# [60]	validation_0-auc:0.829264	validation_1-auc:0.827871
# [61]	validation_0-auc:0.830248	validation_1-auc:0.828997
# [62]	validation_0-auc:0.830703	validation_1-auc:0.829357
# [63]	validation_0-auc:0.832799	validation_1-auc:0.831277
# [64]	validation_0-auc:0.833221	validation_1-auc:0.831443
# [65]	validation_0-auc:0.833797	validation_1-auc:0.831057
# [66]	validation_0-auc:0.834813	validation_1-auc:0.832403
# [67]	validation_0-auc:0.835379	validation_1-auc:0.832981
# [68]	validation_0-auc:0.835569	validation_1-auc:0.832983
# [69]	validation_0-auc:0.836142	validation_1-auc:0.8337
# [70]	validation_0-auc:0.837059	validation_1-auc:0.834597
# [71]	validation_0-auc:0.837225	validation_1-auc:0.834669
# [72]	validation_0-auc:0.838509	validation_1-auc:0.835205
# [73]	validation_0-auc:0.838964	validation_1-auc:0.835416
# [74]	validation_0-auc:0.839935	validation_1-auc:0.836241
# [75]	validation_0-auc:0.84029	validation_1-auc:0.83624
# [76]	validation_0-auc:0.840795	validation_1-auc:0.836618
# [77]	validation_0-auc:0.840998	validation_1-auc:0.836573
# [78]	validation_0-auc:0.841338	validation_1-auc:0.836832
# [79]	validation_0-auc:0.8415	validation_1-auc:0.836727
# [80]	validation_0-auc:0.841707	validation_1-auc:0.836748
# [81]	validation_0-auc:0.841993	validation_1-auc:0.837016
# [82]	validation_0-auc:0.842191	validation_1-auc:0.837223
# [83]	validation_0-auc:0.842404	validation_1-auc:0.837612
# [84]	validation_0-auc:0.843069	validation_1-auc:0.838477
# [85]	validation_0-auc:0.843582	validation_1-auc:0.838757
# [86]	validation_0-auc:0.844198	validation_1-auc:0.839436
# [87]	validation_0-auc:0.84453	validation_1-auc:0.839663
# [88]	validation_0-auc:0.844581	validation_1-auc:0.839742
# [89]	validation_0-auc:0.844727	validation_1-auc:0.839767
# [90]	validation_0-auc:0.845074	validation_1-auc:0.83982
# [91]	validation_0-auc:0.845247	validation_1-auc:0.839905
# [92]	validation_0-auc:0.84545	validation_1-auc:0.839819
# [93]	validation_0-auc:0.845549	validation_1-auc:0.839825
# [94]	validation_0-auc:0.84588	validation_1-auc:0.840168
# [95]	validation_0-auc:0.846017	validation_1-auc:0.840255
# [96]	validation_0-auc:0.846165	validation_1-auc:0.840167
# [97]	validation_0-auc:0.846407	validation_1-auc:0.840363
# [98]	validation_0-auc:0.846701	validation_1-auc:0.840697
# [99]	validation_0-auc:0.84676	validation_1-auc:0.840695
# [100]	validation_0-auc:0.846984	validation_1-auc:0.840888
# [101]	validation_0-auc:0.84703	validation_1-auc:0.840865
# [102]	validation_0-auc:0.847085	validation_1-auc:0.841056
# [103]	validation_0-auc:0.847199	validation_1-auc:0.841192
# [104]	validation_0-auc:0.8472	validation_1-auc:0.841224
# [105]	validation_0-auc:0.847389	validation_1-auc:0.841174
# [106]	validation_0-auc:0.847696	validation_1-auc:0.841164
# [107]	validation_0-auc:0.847803	validation_1-auc:0.841169
# [108]	validation_0-auc:0.847901	validation_1-auc:0.841189
# [109]	validation_0-auc:0.848117	validation_1-auc:0.841317
# [110]	validation_0-auc:0.848156	validation_1-auc:0.841449
# [111]	validation_0-auc:0.848345	validation_1-auc:0.841452
# [112]	validation_0-auc:0.848568	validation_1-auc:0.841522
# [113]	validation_0-auc:0.848742	validation_1-auc:0.841643
# [114]	validation_0-auc:0.848905	validation_1-auc:0.841806
# [115]	validation_0-auc:0.849056	validation_1-auc:0.841973
# [116]	validation_0-auc:0.849163	validation_1-auc:0.842012
# [117]	validation_0-auc:0.8493	validation_1-auc:0.842013
# [118]	validation_0-auc:0.849396	validation_1-auc:0.84201
# [119]	validation_0-auc:0.849493	validation_1-auc:0.842024
# [120]	validation_0-auc:0.849666	validation_1-auc:0.84229
# [121]	validation_0-auc:0.849787	validation_1-auc:0.842255
# [122]	validation_0-auc:0.849901	validation_1-auc:0.842366
# [123]	validation_0-auc:0.849963	validation_1-auc:0.842312
# [124]	validation_0-auc:0.850009	validation_1-auc:0.842303
# [125]	validation_0-auc:0.850029	validation_1-auc:0.842332
# [126]	validation_0-auc:0.850186	validation_1-auc:0.842364
# [127]	validation_0-auc:0.850294	validation_1-auc:0.84247
# [128]	validation_0-auc:0.850529	validation_1-auc:0.842472
# [129]	validation_0-auc:0.850565	validation_1-auc:0.842459
# [130]	validation_0-auc:0.85069	validation_1-auc:0.842472
# [131]	validation_0-auc:0.850799	validation_1-auc:0.842656
# [132]	validation_0-auc:0.850886	validation_1-auc:0.842639
# [133]	validation_0-auc:0.850965	validation_1-auc:0.842594
# [134]	validation_0-auc:0.851074	validation_1-auc:0.842663
# [135]	validation_0-auc:0.851272	validation_1-auc:0.842704
# [136]	validation_0-auc:0.851342	validation_1-auc:0.842676
# [137]	validation_0-auc:0.851409	validation_1-auc:0.842607
# [138]	validation_0-auc:0.851432	validation_1-auc:0.842646
# [139]	validation_0-auc:0.851501	validation_1-auc:0.842609
# [140]	validation_0-auc:0.851613	validation_1-auc:0.842648
# [141]	validation_0-auc:0.851879	validation_1-auc:0.842619
# [142]	validation_0-auc:0.852113	validation_1-auc:0.842654
# [143]	validation_0-auc:0.852375	validation_1-auc:0.842687
# [144]	validation_0-auc:0.852407	validation_1-auc:0.842687
# [145]	validation_0-auc:0.852469	validation_1-auc:0.84272
# [146]	validation_0-auc:0.852558	validation_1-auc:0.84271
# [147]	validation_0-auc:0.852771	validation_1-auc:0.842723
# [148]	validation_0-auc:0.852951	validation_1-auc:0.842752
# [149]	validation_0-auc:0.853054	validation_1-auc:0.842729
# [150]	validation_0-auc:0.85317	validation_1-auc:0.842765
# [151]	validation_0-auc:0.853248	validation_1-auc:0.842778
# [152]	validation_0-auc:0.853316	validation_1-auc:0.842802
# [153]	validation_0-auc:0.853342	validation_1-auc:0.842768
# [154]	validation_0-auc:0.853435	validation_1-auc:0.842716
# [155]	validation_0-auc:0.853546	validation_1-auc:0.842764
# [156]	validation_0-auc:0.853635	validation_1-auc:0.842726
# [157]	validation_0-auc:0.853702	validation_1-auc:0.84272
# [158]	validation_0-auc:0.853804	validation_1-auc:0.842746
# [159]	validation_0-auc:0.853888	validation_1-auc:0.842746
# [160]	validation_0-auc:0.853957	validation_1-auc:0.84278
# [161]	validation_0-auc:0.853961	validation_1-auc:0.84277
# [162]	validation_0-auc:0.854005	validation_1-auc:0.842761
# [163]	validation_0-auc:0.854055	validation_1-auc:0.842705
# [164]	validation_0-auc:0.854087	validation_1-auc:0.842647
# [165]	validation_0-auc:0.85418	validation_1-auc:0.842692
# [166]	validation_0-auc:0.854283	validation_1-auc:0.84275
# [167]	validation_0-auc:0.854467	validation_1-auc:0.842552
# [168]	validation_0-auc:0.854554	validation_1-auc:0.842564
# [169]	validation_0-auc:0.854798	validation_1-auc:0.842565
# [170]	validation_0-auc:0.854855	validation_1-auc:0.842587
# [171]	validation_0-auc:0.855015	validation_1-auc:0.842637
# [172]	validation_0-auc:0.855133	validation_1-auc:0.842667
# [173]	validation_0-auc:0.8552	validation_1-auc:0.842613
# [174]	validation_0-auc:0.855296	validation_1-auc:0.842698
# [175]	validation_0-auc:0.855349	validation_1-auc:0.842647
# [176]	validation_0-auc:0.855364	validation_1-auc:0.842583
# [177]	validation_0-auc:0.855531	validation_1-auc:0.842638
# [178]	validation_0-auc:0.855625	validation_1-auc:0.842683
# [179]	validation_0-auc:0.85564	validation_1-auc:0.842722
# [180]	validation_0-auc:0.855711	validation_1-auc:0.842762
# [181]	validation_0-auc:0.855789	validation_1-auc:0.842695
# [182]	validation_0-auc:0.855912	validation_1-auc:0.842694
# [183]	validation_0-auc:0.855959	validation_1-auc:0.842694
# [184]	validation_0-auc:0.856036	validation_1-auc:0.842739
# [185]	validation_0-auc:0.856108	validation_1-auc:0.842734
# [186]	validation_0-auc:0.856194	validation_1-auc:0.842695
# [187]	validation_0-auc:0.856243	validation_1-auc:0.842738
# [188]	validation_0-auc:0.856281	validation_1-auc:0.842726
# [189]	validation_0-auc:0.856285	validation_1-auc:0.842732
# [190]	validation_0-auc:0.856328	validation_1-auc:0.842752
# [191]	validation_0-auc:0.856364	validation_1-auc:0.842797
# [192]	validation_0-auc:0.856415	validation_1-auc:0.842829
# [193]	validation_0-auc:0.856453	validation_1-auc:0.842805
# [194]	validation_0-auc:0.856544	validation_1-auc:0.842811
# [195]	validation_0-auc:0.856583	validation_1-auc:0.84285
# [196]	validation_0-auc:0.85666	validation_1-auc:0.842874
# [197]	validation_0-auc:0.856704	validation_1-auc:0.842899
# [198]	validation_0-auc:0.856768	validation_1-auc:0.84288
# [199]	validation_0-auc:0.856848	validation_1-auc:0.842907
# [200]	validation_0-auc:0.856938	validation_1-auc:0.842881
# [201]	validation_0-auc:0.856957	validation_1-auc:0.842871
# [202]	validation_0-auc:0.857029	validation_1-auc:0.842792
# [203]	validation_0-auc:0.857121	validation_1-auc:0.842784
# [204]	validation_0-auc:0.85717	validation_1-auc:0.842752
# [205]	validation_0-auc:0.85725	validation_1-auc:0.842712
# [206]	validation_0-auc:0.857342	validation_1-auc:0.842684
# [207]	validation_0-auc:0.857404	validation_1-auc:0.842646
# [208]	validation_0-auc:0.857448	validation_1-auc:0.842686
# [209]	validation_0-auc:0.857555	validation_1-auc:0.842734
# [210]	validation_0-auc:0.857623	validation_1-auc:0.842668
# [211]	validation_0-auc:0.85765	validation_1-auc:0.842716
# [212]	validation_0-auc:0.857692	validation_1-auc:0.842618
# [213]	validation_0-auc:0.857783	validation_1-auc:0.842643
# [214]	validation_0-auc:0.857868	validation_1-auc:0.842526
# [215]	validation_0-auc:0.857921	validation_1-auc:0.842447
# [216]	validation_0-auc:0.858079	validation_1-auc:0.842425
# [217]	validation_0-auc:0.858147	validation_1-auc:0.842364
# [218]	validation_0-auc:0.858201	validation_1-auc:0.842401
# [219]	validation_0-auc:0.858281	validation_1-auc:0.842372
# [220]	validation_0-auc:0.858403	validation_1-auc:0.842496
# [221]	validation_0-auc:0.858468	validation_1-auc:0.842469
# [222]	validation_0-auc:0.858505	validation_1-auc:0.842484
# [223]	validation_0-auc:0.858699	validation_1-auc:0.842482
# [224]	validation_0-auc:0.858763	validation_1-auc:0.84249
# [225]	validation_0-auc:0.858823	validation_1-auc:0.842479
# [226]	validation_0-auc:0.858889	validation_1-auc:0.842489
# [227]	validation_0-auc:0.859003	validation_1-auc:0.842491
# [228]	validation_0-auc:0.859042	validation_1-auc:0.842437
# [229]	validation_0-auc:0.859101	validation_1-auc:0.842437
# [230]	validation_0-auc:0.859111	validation_1-auc:0.84243
# [231]	validation_0-auc:0.859185	validation_1-auc:0.842362
# [232]	validation_0-auc:0.859202	validation_1-auc:0.84239
# [233]	validation_0-auc:0.859269	validation_1-auc:0.842367
# [234]	validation_0-auc:0.859287	validation_1-auc:0.842372
# [235]	validation_0-auc:0.859354	validation_1-auc:0.842337
# [236]	validation_0-auc:0.859442	validation_1-auc:0.84238
# [237]	validation_0-auc:0.859551	validation_1-auc:0.8424
# [238]	validation_0-auc:0.859635	validation_1-auc:0.842407
# [239]	validation_0-auc:0.85966	validation_1-auc:0.842359
# [240]	validation_0-auc:0.859737	validation_1-auc:0.842402
# [241]	validation_0-auc:0.859881	validation_1-auc:0.842423
# [242]	validation_0-auc:0.859971	validation_1-auc:0.842513
# [243]	validation_0-auc:0.860022	validation_1-auc:0.842448
# [244]	validation_0-auc:0.86007	validation_1-auc:0.84246
# [245]	validation_0-auc:0.860118	validation_1-auc:0.84245
# [246]	validation_0-auc:0.860155	validation_1-auc:0.842433
# [247]	validation_0-auc:0.860244	validation_1-auc:0.842374
# [248]	validation_0-auc:0.860324	validation_1-auc:0.842342
# [249]	validation_0-auc:0.860353	validation_1-auc:0.84231
# Stopping. Best iteration:
# [199]	validation_0-auc:0.856848	validation_1-auc:0.842907
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=3, missing=9999999999, n_estimators=1000,
#               n_jobs=1, nthread=4, objective='binary:logistic', random_state=0,
#               reg_alpha=0.03, reg_lambda=1,
#               scale_pos_weight=0.041198707061852843, seed=1301, silent=None,
#               subsample=1.0, verbosity=1)

# %%
print('Overall AUC:', roc_auc_score(y, clf.predict_proba(X_sel, ntree_limit=clf.best_iteration)[:,1]))
# Out:
# Overall AUC: 0.851214050558

# %%
test['n0'] = (test == 0).sum(axis=1)
# test['logvar38'] = test['var38'].map(np.log1p)
# # Encode var36 as category
# test['var36'] = test['var36'].astype('category')
# test = pd.get_dummies(test)
test_normalized = normalize(test, axis=0)
pca = PCA(n_components=2)
test_pca = pca.fit_transform(test_normalized)
test['PCA1'] = test_pca[:,0]
test['PCA2'] = test_pca[:,1]
sel_test = test[features]    
y_pred = clf.predict_proba(sel_test, ntree_limit=clf.best_iteration)

# %%
submission = pd.DataFrame({"ID":test.index, "TARGET":y_pred[:,1]})
submission.to_csv("submission.csv", index=False)

# %%
submission
# Out:
#            ID    TARGET
# 0           2  0.002862
# 1           5  0.002532
# 2           6  0.000131
# 3           7  0.000579
# 4           9  0.000128
# 5          11  0.008331
# 6          12  0.003967
# 7          15  0.007796
# 8          16  0.000899
# 9          17  0.000604
# 10         19  0.001010
# 11         21  0.000184
# 12         22  0.000597
# 13         24  0.000485
# 14         27  0.000632
# 15         28  0.000710
# 16         30  0.009348
# 17         33  0.000172
# 18         35  0.000529
# 19         37  0.000716
# 20         38  0.000894
# 21         40  0.005540
# 22         41  0.001184
# 23         44  0.000835
# 24         46  0.005535
# 25         47  0.000332
# 26         48  0.000198
# 27         50  0.000195
# 28         52  0.007269
# 29         53  0.000394
# ...       ...       ...
# 75788  151772  0.000365
# 75789  151773  0.001406
# 75790  151776  0.000450
# 75791  151777  0.000546
# 75792  151780  0.000339
# 75793  151781  0.000888
# 75794  151782  0.008727
# 75795  151784  0.023221
# 75796  151785  0.001142
# 75797  151786  0.012094
# 75798  151788  0.000147
# 75799  151789  0.000127
# 75800  151790  0.001210
# 75801  151791  0.000851
# 75802  151803  0.000978
# 75803  151812  0.002313
# 75804  151814  0.001127
# 75805  151817  0.001387
# 75806  151819  0.004292
# 75807  151822  0.000232
# 75808  151823  0.002025
# 75809  151824  0.005401
# 75810  151826  0.000497
# 75811  151827  0.000848
# 75812  151828  0.000178
# 75813  151831  0.001946
# 75814  151832  0.000757
# 75815  151833  0.000161
# 75816  151834  0.002315
# 75817  151837  0.000099
#
# [75818 rows x 2 columns]

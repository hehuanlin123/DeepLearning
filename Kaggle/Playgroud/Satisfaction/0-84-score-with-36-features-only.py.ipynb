# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("Agg") #Needed to save figures
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import roc_auc_score

training = pd.read_csv("/Users/szkfzx/datasets/santander-customer-satisfaction/train.csv")
test = pd.read_csv("/Users/szkfzx/datasets/santander-customer-satisfaction/test.csv")

print(training.shape)
print(test.shape)

# Replace -999999 in var3 column with most common value 2 
# See https://www.kaggle.com/cast42/santander-customer-satisfaction/debugging-var3-999999
# for details
training = training.replace(-999999,2)


# Replace 9999999999 with NaN
# See https://www.kaggle.com/c/santander-customer-satisfaction/forums/t/19291/data-dictionary/111360#post111360
# training = training.replace(9999999999, np.nan)
# training.dropna(inplace=True)
# Leads to validation_0-auc:0.839577

X = training.iloc[:,:-1]
y = training.TARGET

# Add zeros per row as extra feature
X['n0'] = (X == 0).sum(axis=1)
# # Add log of var38
# X['logvar38'] = X['var38'].map(np.log1p)
# # Encode var36 as category
# X['var36'] = X['var36'].astype('category')
# X = pd.get_dummies(X)

# Add PCA components as features
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

X_normalized = normalize(X, axis=0)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_normalized)
X['PCA1'] = X_pca[:,0]
X['PCA2'] = X_pca[:,1]

from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import f_classif,chi2
from sklearn.preprocessing import Binarizer, scale

p = 86 # 308 features validation_1-auc:0.848039
p = 80 # 284 features validation_1-auc:0.848414
p = 77 # 267 features validation_1-auc:0.848000
p = 75 # 261 features validation_1-auc:0.848642
# p = 73 # 257 features validation_1-auc:0.848338
# p = 70 # 259 features validation_1-auc:0.848588
# p = 69 # 238 features validation_1-auc:0.848547
# p = 67 # 247 features validation_1-auc:0.847925
# p = 65 # 240 features validation_1-auc:0.846769
# p = 60 # 222 features validation_1-auc:0.848581

X_bin = Binarizer().fit_transform(scale(X))
selectChi2 = SelectPercentile(chi2, percentile=p).fit(X_bin, y)
selectF_classif = SelectPercentile(f_classif, percentile=p).fit(X, y)

chi2_selected = selectChi2.get_support()
chi2_selected_features = [ f for i,f in enumerate(X.columns) if chi2_selected[i]]
print('Chi2 selected {} features {}.'.format(chi2_selected.sum(),
   chi2_selected_features))
f_classif_selected = selectF_classif.get_support()
f_classif_selected_features = [ f for i,f in enumerate(X.columns) if f_classif_selected[i]]
print('F_classif selected {} features {}.'.format(f_classif_selected.sum(),
   f_classif_selected_features))
selected = chi2_selected & f_classif_selected
print('Chi2 & F_classif selected {} features'.format(selected.sum()))
features = [ f for f,s in zip(X.columns, selected) if s]
print (features)

X_sel = X[features]

X_train, X_test, y_train, y_test = train_test_split(X_sel, y, random_state=1301, stratify=y, test_size=0.4)

# xgboost parameter tuning with p = 75
# recipe: https://www.kaggle.com/c/bnp-paribas-cardif-claims-management/forums/t/19083/best-practices-for-parameter-tuning-on-models/108783#post108783

ratio = float(np.sum(y == 1)) / np.sum(y==0)
# Initial parameters for the parameter exploration
# clf = xgb.XGBClassifier(missing=9999999999,
#                 max_depth = 10,
#                 n_estimators=1000,
#                 learning_rate=0.1, 
#                 nthread=4,
#                 subsample=1.0,
#                 colsample_bytree=0.5,
#                 min_child_weight = 5,
#                 scale_pos_weight = ratio,
#                 seed=4242)

# gives : validation_1-auc:0.845644
# max_depth=8 -> validation_1-auc:0.846341
# max_depth=6 -> validation_1-auc:0.845738
# max_depth=7 -> validation_1-auc:0.846504
# subsample=0.8 -> validation_1-auc:0.844440
# subsample=0.9 -> validation_1-auc:0.844746
# subsample=1.0,  min_child_weight=8 -> validation_1-auc:0.843393
# min_child_weight=3 -> validation_1-auc:0.848534
# min_child_weight=1 -> validation_1-auc:0.846311
# min_child_weight=4 -> validation_1-auc:0.847994
# min_child_weight=2 -> validation_1-auc:0.847934
# min_child_weight=3, colsample_bytree=0.3 -> validation_1-auc:0.847498
# colsample_bytree=0.7 -> validation_1-auc:0.846984
# colsample_bytree=0.6 -> validation_1-auc:0.847856
# colsample_bytree=0.5, learning_rate=0.05 -> validation_1-auc:0.847347
# max_depth=8 -> validation_1-auc:0.847352
# learning_rate = 0.07 -> validation_1-auc:0.847432
# learning_rate = 0.2 -> validation_1-auc:0.846444
# learning_rate = 0.15 -> validation_1-auc:0.846889
# learning_rate = 0.09 -> validation_1-auc:0.846680
# learning_rate = 0.1 -> validation_1-auc:0.847432
# max_depth=7 -> validation_1-auc:0.848534
# learning_rate = 0.05 -> validation_1-auc:0.847347
# 

clf = xgb.XGBClassifier(missing=9999999999,
                max_depth = 5,
                n_estimators=1000,
                learning_rate=0.1, 
                nthread=4,
                subsample=1.0,
                colsample_bytree=0.5,
                min_child_weight = 3,
                scale_pos_weight = ratio,
                reg_alpha=0.03,
                seed=1301)
                
clf.fit(X_train, y_train, early_stopping_rounds=50, eval_metric="auc",
        eval_set=[(X_train, y_train), (X_test, y_test)])
        
print('Overall AUC:', roc_auc_score(y, clf.predict_proba(X_sel, ntree_limit=clf.best_iteration)[:,1]))

test['n0'] = (test == 0).sum(axis=1)
# test['logvar38'] = test['var38'].map(np.log1p)
# # Encode var36 as category
# test['var36'] = test['var36'].astype('category')
# test = pd.get_dummies(test)
test_normalized = normalize(test, axis=0)
pca = PCA(n_components=2)
test_pca = pca.fit_transform(test_normalized)
test['PCA1'] = test_pca[:,0]
test['PCA2'] = test_pca[:,1]
sel_test = test[features]    
y_pred = clf.predict_proba(sel_test, ntree_limit=clf.best_iteration)

submission = pd.DataFrame({"ID":test.index, "TARGET":y_pred[:,1]})
submission.to_csv("submission.csv", index=False)

submission
# Out:
# (76020, 371)
# (75818, 370)
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:172: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:114: UserWarning: Features [ 22  23  57  58  59  60  81  85  86 132 133 134 135 156 162 163 180 181
#  190 193 221 223 235 239 245 249 262 263 304 308 316 320 328 350] are constant.
#   UserWarning)
# /Users/szkfzx/anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:115: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# Chi2 selected 279 features ['ID', 'var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'imp_sal_var16_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var40_ult3', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var35', 'num_var37_med_ult2', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var1', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var17', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_hace3', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_emit_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_in_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_hace3', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3 ...
# F_classif selected 279 features ['ID', 'var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var6', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13_medio_0', 'num_var13_medio', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var18_0', 'num_var18', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var29', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var34_0', 'num_var35', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_amort_var18_1y3', 'delta_imp_amort_var34_1y3', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_reemb_var17_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var7_recib_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto ...
# Chi2 & F_classif selected 263 features
# ['ID', 'var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var35', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3', 'num_meses_var17_ult3', 'num_meses_var29_ult3', 'num_meses_var33_ult3', 'num_meses_var39_vig_ult3', 'num_meses_var44_ult3', 'num_op_var39_comer_ult1', 'num_op_var40_comer_ult1', 'num_op_var40_comer_ult3', 'num_op_var40_efect_ult1', 'num_op_var4 ...
# [0]	validation_0-auc:0.5	validation_1-auc:0.5
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 50 rounds.
# [1]	validation_0-auc:0.5	validation_1-auc:0.5
# [2]	validation_0-auc:0.5	validation_1-auc:0.5
# [3]	validation_0-auc:0.5	validation_1-auc:0.5
# [4]	validation_0-auc:0.5	validation_1-auc:0.5
# [5]	validation_0-auc:0.5	validation_1-auc:0.5
# [6]	validation_0-auc:0.5	validation_1-auc:0.5
# [7]	validation_0-auc:0.5	validation_1-auc:0.5
# [8]	validation_0-auc:0.5	validation_1-auc:0.5
# [9]	validation_0-auc:0.5	validation_1-auc:0.5
# [10]	validation_0-auc:0.5	validation_1-auc:0.5
# [11]	validation_0-auc:0.5	validation_1-auc:0.5
# [12]	validation_0-auc:0.5	validation_1-auc:0.5
# [13]	validation_0-auc:0.5	validation_1-auc:0.5
# [14]	validation_0-auc:0.5	validation_1-auc:0.5
# [15]	validation_0-auc:0.5	validation_1-auc:0.5
# [16]	validation_0-auc:0.5	validation_1-auc:0.5
# [17]	validation_0-auc:0.5	validation_1-auc:0.5
# [18]	validation_0-auc:0.5	validation_1-auc:0.5
# [19]	validation_0-auc:0.679193	validation_1-auc:0.682766
# [20]	validation_0-auc:0.712395	validation_1-auc:0.716866
# [21]	validation_0-auc:0.712395	validation_1-auc:0.716866
# [22]	validation_0-auc:0.712395	validation_1-auc:0.716866
# [23]	validation_0-auc:0.712433	validation_1-auc:0.716929
# [24]	validation_0-auc:0.712215	validation_1-auc:0.71681
# [25]	validation_0-auc:0.710949	validation_1-auc:0.717025
# [26]	validation_0-auc:0.710902	validation_1-auc:0.716932
# [27]	validation_0-auc:0.714749	validation_1-auc:0.720255
# [28]	validation_0-auc:0.716563	validation_1-auc:0.721662
# [29]	validation_0-auc:0.715676	validation_1-auc:0.719346
# [30]	validation_0-auc:0.715241	validation_1-auc:0.719289
# [31]	validation_0-auc:0.715546	validation_1-auc:0.719474
# [32]	validation_0-auc:0.724397	validation_1-auc:0.727133
# [33]	validation_0-auc:0.725185	validation_1-auc:0.728114
# [34]	validation_0-auc:0.727392	validation_1-auc:0.728871
# [35]	validation_0-auc:0.729044	validation_1-auc:0.730301
# [36]	validation_0-auc:0.72996	validation_1-auc:0.731084
# [37]	validation_0-auc:0.734805	validation_1-auc:0.734148
# [38]	validation_0-auc:0.736381	validation_1-auc:0.735068
# [39]	validation_0-auc:0.774738	validation_1-auc:0.777789
# [40]	validation_0-auc:0.775393	validation_1-auc:0.778238
# [41]	validation_0-auc:0.776347	validation_1-auc:0.77896
# [42]	validation_0-auc:0.792061	validation_1-auc:0.79259
# [43]	validation_0-auc:0.799841	validation_1-auc:0.798925
# [44]	validation_0-auc:0.80081	validation_1-auc:0.799812
# [45]	validation_0-auc:0.803647	validation_1-auc:0.800838
# [46]	validation_0-auc:0.80486	validation_1-auc:0.801705
# [47]	validation_0-auc:0.804951	validation_1-auc:0.802604
# [48]	validation_0-auc:0.804045	validation_1-auc:0.801552
# [49]	validation_0-auc:0.803979	validation_1-auc:0.802321
# [50]	validation_0-auc:0.809799	validation_1-auc:0.808392
# [51]	validation_0-auc:0.807976	validation_1-auc:0.806577
# [52]	validation_0-auc:0.816012	validation_1-auc:0.814444
# [53]	validation_0-auc:0.815412	validation_1-auc:0.814232
# [54]	validation_0-auc:0.817147	validation_1-auc:0.815524
# [55]	validation_0-auc:0.822658	validation_1-auc:0.821142
# [56]	validation_0-auc:0.82329	validation_1-auc:0.82159
# [57]	validation_0-auc:0.823552	validation_1-auc:0.821453
# [58]	validation_0-auc:0.827076	validation_1-auc:0.824312
# [59]	validation_0-auc:0.829076	validation_1-auc:0.826227
# [60]	validation_0-auc:0.830017	validation_1-auc:0.827789
# [61]	validation_0-auc:0.831549	validation_1-auc:0.82937
# [62]	validation_0-auc:0.831376	validation_1-auc:0.828694
# [63]	validation_0-auc:0.832334	validation_1-auc:0.8295
# [64]	validation_0-auc:0.833568	validation_1-auc:0.830768
# [65]	validation_0-auc:0.834565	validation_1-auc:0.831568
# [66]	validation_0-auc:0.835068	validation_1-auc:0.832252
# [67]	validation_0-auc:0.836498	validation_1-auc:0.833388
# [68]	validation_0-auc:0.836837	validation_1-auc:0.833475
# [69]	validation_0-auc:0.837563	validation_1-auc:0.833906
# [70]	validation_0-auc:0.838089	validation_1-auc:0.83446
# [71]	validation_0-auc:0.838951	validation_1-auc:0.835252
# [72]	validation_0-auc:0.838876	validation_1-auc:0.835036
# [73]	validation_0-auc:0.839279	validation_1-auc:0.835212
# [74]	validation_0-auc:0.839575	validation_1-auc:0.835166
# [75]	validation_0-auc:0.840574	validation_1-auc:0.83566
# [76]	validation_0-auc:0.840669	validation_1-auc:0.83545
# [77]	validation_0-auc:0.84116	validation_1-auc:0.835873
# [78]	validation_0-auc:0.841806	validation_1-auc:0.836721
# [79]	validation_0-auc:0.842188	validation_1-auc:0.836913
# [80]	validation_0-auc:0.842283	validation_1-auc:0.836571
# [81]	validation_0-auc:0.842667	validation_1-auc:0.837053
# [82]	validation_0-auc:0.84282	validation_1-auc:0.836955
# [83]	validation_0-auc:0.842969	validation_1-auc:0.836999
# [84]	validation_0-auc:0.8433	validation_1-auc:0.8372
# [85]	validation_0-auc:0.843675	validation_1-auc:0.837777
# [86]	validation_0-auc:0.844143	validation_1-auc:0.837927
# [87]	validation_0-auc:0.844183	validation_1-auc:0.837836
# [88]	validation_0-auc:0.844356	validation_1-auc:0.837858
# [89]	validation_0-auc:0.844923	validation_1-auc:0.838425
# [90]	validation_0-auc:0.845442	validation_1-auc:0.838869
# [91]	validation_0-auc:0.845616	validation_1-auc:0.839222
# [92]	validation_0-auc:0.845926	validation_1-auc:0.839316
# [93]	validation_0-auc:0.846348	validation_1-auc:0.839389
# [94]	validation_0-auc:0.84665	validation_1-auc:0.839545
# [95]	validation_0-auc:0.846792	validation_1-auc:0.839553
# [96]	validation_0-auc:0.847047	validation_1-auc:0.839618
# [97]	validation_0-auc:0.847127	validation_1-auc:0.839518
# [98]	validation_0-auc:0.847246	validation_1-auc:0.83959
# [99]	validation_0-auc:0.847407	validation_1-auc:0.839697
# [100]	validation_0-auc:0.847613	validation_1-auc:0.83984
# [101]	validation_0-auc:0.847732	validation_1-auc:0.839817
# [102]	validation_0-auc:0.847755	validation_1-auc:0.839801
# [103]	validation_0-auc:0.847878	validation_1-auc:0.839799
# [104]	validation_0-auc:0.848146	validation_1-auc:0.839972
# [105]	validation_0-auc:0.848269	validation_1-auc:0.840273
# [106]	validation_0-auc:0.84836	validation_1-auc:0.840453
# [107]	validation_0-auc:0.848519	validation_1-auc:0.840454
# [108]	validation_0-auc:0.848591	validation_1-auc:0.840592
# [109]	validation_0-auc:0.848724	validation_1-auc:0.840662
# [110]	validation_0-auc:0.848863	validation_1-auc:0.840542
# [111]	validation_0-auc:0.849021	validation_1-auc:0.840602
# [112]	validation_0-auc:0.849088	validation_1-auc:0.840664
# [113]	validation_0-auc:0.84933	validation_1-auc:0.840859
# [114]	validation_0-auc:0.849506	validation_1-auc:0.84088
# [115]	validation_0-auc:0.849695	validation_1-auc:0.841043
# [116]	validation_0-auc:0.849822	validation_1-auc:0.841145
# [117]	validation_0-auc:0.850104	validation_1-auc:0.841139
# [118]	validation_0-auc:0.850094	validation_1-auc:0.841207
# [119]	validation_0-auc:0.850264	validation_1-auc:0.841411
# [120]	validation_0-auc:0.850276	validation_1-auc:0.841439
# [121]	validation_0-auc:0.850338	validation_1-auc:0.841384
# [122]	validation_0-auc:0.850402	validation_1-auc:0.841347
# [123]	validation_0-auc:0.850555	validation_1-auc:0.84148
# [124]	validation_0-auc:0.850691	validation_1-auc:0.841646
# [125]	validation_0-auc:0.850834	validation_1-auc:0.841648
# [126]	validation_0-auc:0.850975	validation_1-auc:0.841577
# [127]	validation_0-auc:0.851029	validation_1-auc:0.841481
# [128]	validation_0-auc:0.851168	validation_1-auc:0.841422
# [129]	validation_0-auc:0.851258	validation_1-auc:0.841381
# [130]	validation_0-auc:0.85132	validation_1-auc:0.841463
# [131]	validation_0-auc:0.851351	validation_1-auc:0.841481
# [132]	validation_0-auc:0.851509	validation_1-auc:0.841354
# [133]	validation_0-auc:0.851645	validation_1-auc:0.841421
# [134]	validation_0-auc:0.851909	validation_1-auc:0.8416
# [135]	validation_0-auc:0.852065	validation_1-auc:0.841657
# [136]	validation_0-auc:0.85213	validation_1-auc:0.841733
# [137]	validation_0-auc:0.852273	validation_1-auc:0.84177
# [138]	validation_0-auc:0.852295	validation_1-auc:0.841778
# [139]	validation_0-auc:0.852479	validation_1-auc:0.841716
# [140]	validation_0-auc:0.852646	validation_1-auc:0.84172
# [141]	validation_0-auc:0.852818	validation_1-auc:0.841747
# [142]	validation_0-auc:0.85301	validation_1-auc:0.841752
# [143]	validation_0-auc:0.853184	validation_1-auc:0.841546
# [144]	validation_0-auc:0.853282	validation_1-auc:0.841532
# [145]	validation_0-auc:0.853428	validation_1-auc:0.841543
# [146]	validation_0-auc:0.853559	validation_1-auc:0.841525
# [147]	validation_0-auc:0.853604	validation_1-auc:0.841535
# [148]	validation_0-auc:0.853669	validation_1-auc:0.841553
# [149]	validation_0-auc:0.853725	validation_1-auc:0.841515
# [150]	validation_0-auc:0.853818	validation_1-auc:0.841575
# [151]	validation_0-auc:0.853935	validation_1-auc:0.84161
# [152]	validation_0-auc:0.854035	validation_1-auc:0.841597
# [153]	validation_0-auc:0.854104	validation_1-auc:0.841691
# [154]	validation_0-auc:0.854312	validation_1-auc:0.841657
# [155]	validation_0-auc:0.854429	validation_1-auc:0.841692
# [156]	validation_0-auc:0.854512	validation_1-auc:0.841683
# [157]	validation_0-auc:0.854539	validation_1-auc:0.84168
# [158]	validation_0-auc:0.854605	validation_1-auc:0.841699
# [159]	validation_0-auc:0.854795	validation_1-auc:0.841826
# [160]	validation_0-auc:0.854955	validation_1-auc:0.84179
# [161]	validation_0-auc:0.855035	validation_1-auc:0.841758
# [162]	validation_0-auc:0.855088	validation_1-auc:0.841782
# [163]	validation_0-auc:0.855215	validation_1-auc:0.84167
# [164]	validation_0-auc:0.855316	validation_1-auc:0.841613
# [165]	validation_0-auc:0.85533	validation_1-auc:0.841566
# [166]	validation_0-auc:0.855594	validation_1-auc:0.841741
# [167]	validation_0-auc:0.855666	validation_1-auc:0.84172
# [168]	validation_0-auc:0.855794	validation_1-auc:0.841815
# [169]	validation_0-auc:0.855901	validation_1-auc:0.841871
# [170]	validation_0-auc:0.85595	validation_1-auc:0.841819
# [171]	validation_0-auc:0.856021	validation_1-auc:0.841803
# [172]	validation_0-auc:0.85613	validation_1-auc:0.841881
# [173]	validation_0-auc:0.856321	validation_1-auc:0.841989
# [174]	validation_0-auc:0.856449	validation_1-auc:0.841908
# [175]	validation_0-auc:0.856575	validation_1-auc:0.841821
# [176]	validation_0-auc:0.85666	validation_1-auc:0.841735
# [177]	validation_0-auc:0.856737	validation_1-auc:0.841754
# [178]	validation_0-auc:0.856785	validation_1-auc:0.841785
# [179]	validation_0-auc:0.856856	validation_1-auc:0.841765
# [180]	validation_0-auc:0.856941	validation_1-auc:0.841786
# [181]	validation_0-auc:0.857075	validation_1-auc:0.841834
# [182]	validation_0-auc:0.857146	validation_1-auc:0.841834
# [183]	validation_0-auc:0.857281	validation_1-auc:0.841808
# [184]	validation_0-auc:0.85739	validation_1-auc:0.841792
# [185]	validation_0-auc:0.857526	validation_1-auc:0.841766
# [186]	validation_0-auc:0.857583	validation_1-auc:0.841761
# [187]	validation_0-auc:0.857728	validation_1-auc:0.841797
# [188]	validation_0-auc:0.857773	validation_1-auc:0.841803
# [189]	validation_0-auc:0.85778	validation_1-auc:0.841785
# [190]	validation_0-auc:0.857803	validation_1-auc:0.841819
# [191]	validation_0-auc:0.857894	validation_1-auc:0.841815
# [192]	validation_0-auc:0.858002	validation_1-auc:0.841834
# [193]	validation_0-auc:0.858079	validation_1-auc:0.841843
# [194]	validation_0-auc:0.858157	validation_1-auc:0.841815
# [195]	validation_0-auc:0.858245	validation_1-auc:0.841829
# [196]	validation_0-auc:0.858313	validation_1-auc:0.841825
# [197]	validation_0-auc:0.858376	validation_1-auc:0.841865
# [198]	validation_0-auc:0.858368	validation_1-auc:0.841806
# [199]	validation_0-auc:0.85847	validation_1-auc:0.84174
# [200]	validation_0-auc:0.858544	validation_1-auc:0.841776
# [201]	validation_0-auc:0.858727	validation_1-auc:0.841677
# [202]	validation_0-auc:0.858787	validation_1-auc:0.84171
# [203]	validation_0-auc:0.858864	validation_1-auc:0.841653
# [204]	validation_0-auc:0.858943	validation_1-auc:0.841638
# [205]	validation_0-auc:0.859007	validation_1-auc:0.84162
# [206]	validation_0-auc:0.859021	validation_1-auc:0.841595
# [207]	validation_0-auc:0.859143	validation_1-auc:0.841637
# [208]	validation_0-auc:0.859171	validation_1-auc:0.84163
# [209]	validation_0-auc:0.859282	validation_1-auc:0.841671
# [210]	validation_0-auc:0.859345	validation_1-auc:0.84169
# [211]	validation_0-auc:0.859416	validation_1-auc:0.841776
# [212]	validation_0-auc:0.859478	validation_1-auc:0.841772
# [213]	validation_0-auc:0.859561	validation_1-auc:0.841734
# [214]	validation_0-auc:0.85959	validation_1-auc:0.841758
# [215]	validation_0-auc:0.859648	validation_1-auc:0.841699
# [216]	validation_0-auc:0.859682	validation_1-auc:0.841703
# [217]	validation_0-auc:0.859779	validation_1-auc:0.841683
# [218]	validation_0-auc:0.859835	validation_1-auc:0.841701
# [219]	validation_0-auc:0.859913	validation_1-auc:0.841633
# [220]	validation_0-auc:0.859959	validation_1-auc:0.84161
# [221]	validation_0-auc:0.859987	validation_1-auc:0.841629
# [222]	validation_0-auc:0.860084	validation_1-auc:0.841631
# [223]	validation_0-auc:0.860169	validation_1-auc:0.841537
# Stopping. Best iteration:
# [173]	validation_0-auc:0.856321	validation_1-auc:0.841989
#
# Overall AUC: 0.850436355332
#           ID    TARGET
# 0          0  0.002639
# 1          1  0.002611
# 2          2  0.000141
# 3          3  0.000800
# 4          4  0.000163
# 5          5  0.008604
# 6          6  0.003899
# 7          7  0.008224
# 8          8  0.000930
# 9          9  0.000834
# 10        10  0.001301
# 11        11  0.000201
# 12        12  0.000577
# 13        13  0.000584
# 14        14  0.000661
# 15        15  0.000834
# 16        16  0.010609
# 17        17  0.000192
# 18        18  0.000689
# 19        19  0.000737
# 20        20  0.001194
# 21        21  0.005692
# 22        22  0.001411
# 23        23  0.000826
# 24        24  0.005679
# 25        25  0.000381
# 26        26  0.000257
# 27        27  0.000207
# 28        28  0.008693
# 29        29  0.000532
# ...      ...       ...
# 75788  75788  0.000365
# 75789  75789  0.001265
# 75790  75790  0.000618
# 75791  75791  0.000620
# 75792  75792  0.000308
# 75793  75793  0.000747
# 75794  75794  0.007659
# 75795  75795  0.017210
# 75796  75796  0.001147
# 75797  75797  0.011465
# 75798  75798  0.000171
# 75799  75799  0.000139
# 75800  75800  0.000959
# 75801  75801  0.000730
# 75802  75802  0.000837
# 75803  75803  0.002268
# 75804  75804  0.001405
# 75805  75805  0.001055
# 75806  75806  0.004099
# 75807  75807  0.000226
# 75808  75808  0.001525
# 75809  75809  0.004529
# 75810  75810  0.000609
# 75811  75811  0.000738
# 75812  75812  0.000214
# 75813  75813  0.001793
# 75814  75814  0.000639
# 75815  75815  0.000172
# 75816  75816  0.001881
# 75817  75817  0.000100
#
# [75818 rows x 2 columns]

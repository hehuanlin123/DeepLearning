# %%
#conding:utf-8
import tensorflow as tf

INPUT_NODE = 784 #28*28像素点
OUTPUT_NODE = 10 #输出10个数
LAYER1_NODE = 500 #隐藏层节点个数

def get_weight(shape,regularizer):
    w = tf.Variable(tf.truncated_normal(shape,stddev=0.1))
    if regularizer != None:
        tf.add_to_collection('losses',tf.contrib.layers.l2_regularizer(regularizer)(w))
    return w

def get_bias(shape):
    b = tf.Variable(tf.zeros(shape))
    return b

def forward(x,regularizer):
    w1 = get_weight([INPUT_NODE,LAYER1_NODE],regularizer)
    b1 = get_bias([LAYER1_NODE])
    y1 = tf.nn.relu(tf.matmul(x,w1)+b1)
    
    w2 = get_weight([LAYER1_NODE,OUTPUT_NODE,],regularizer)
    b2 = get_bias([OUTPUT_NODE])
    y = tf.nn.relu(tf.matmul(y1,w2)+b2)
    
    return y

# %%
#conding:utf-8
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import os
#import mnist_forward

BATCH_SIZE = 200
LEARNING_RATE_BASE = 0.1
LEARNING_RATE_DECAY = 0.99
REGULARIZER = 0.0001
STEPS = 50000
MOVING_AVERAGE_DECAY = 0.99
MODEL_SAVE_PATH = "/Users/he/Desktop/hehuanlin/datasets/mnist/model"
MODEL_NAME = "mnist_model"

def backward(mnist):
    
    x = tf.placeholder(tf.float32,[None,INPUT_NODE])
    y_ = tf.placeholder(tf.float32,[None,OUTPUT_NODE])
    y = forward(x,REGULARIZER)
    global_step = tf.Variable(0,trainable=False)
    
    ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y,labels=tf.argmax(y_,1))
    cem = tf.reduce_mean(ce)
    loss = cem + tf.add_n(tf.get_collection('losses'))
    
    learning_rate = tf.train.exponential_decay(LEARNING_RATE_BASE,
                                               global_step,
                                               mnist.train.num_examples / BATCH_SIZE,
                                               LEARNING_RATE_DECAY,
                                               staircase=True)
    
    train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,
                                                                           global_step=global_step)
    
    ema = tf.train.ExponentialMovingAverage(MOVING_AVERAGE_DECAY,global_step)
    ema_op = ema.apply(tf.trainable_variables())
    with tf.control_dependencies([train_step,ema_op]):
        train_op = tf.no_op(name='train')
        
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        init_op = tf.global_variables_initializer()
        sess.run(init_op)
        
        for i in range(STEPS):
            xs,ys = mnist.train.next_batch(BATCH_SIZE)
            _,loss_value,step = sess.run([train_op,loss,global_step],feed_dict={x:xs,y_:ys})
            if i % 1000 == 0:
                print "After %d training step(s),loss on training batch is %g" % (step,loss_value)
                saver.save(sess,os.path.join(MODEL_SAVE_PATH,MODEL_NAME),global_step=global_step)
                
def main():
    mnist = input_data.read_data_sets("/Users/he/Desktop/hehuanlin/datasets/mnist/data/",one_hot=True)
    backward(mnist)
    
if __name__ == "__main__":
    main()
# Out:
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/train-images-idx3-ubyte.gz
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/train-labels-idx1-ubyte.gz
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/t10k-images-idx3-ubyte.gz
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/t10k-labels-idx1-ubyte.gz
# After 1 training step(s),loss on training batch is 3.09533
# After 1001 training step(s),loss on training batch is 0.506931
# After 2001 training step(s),loss on training batch is 0.441895
# After 3001 training step(s),loss on training batch is 0.380055
# After 4001 training step(s),loss on training batch is 0.38481
# After 5001 training step(s),loss on training batch is 0.364364
# After 6001 training step(s),loss on training batch is 0.350272
# After 7001 training step(s),loss on training batch is 0.311518
# After 8001 training step(s),loss on training batch is 0.315569
# After 9001 training step(s),loss on training batch is 0.340046
# After 10001 training step(s),loss on training batch is 0.313098
# After 11001 training step(s),loss on training batch is 0.295432
# After 12001 training step(s),loss on training batch is 0.297795
# After 13001 training step(s),loss on training batch is 0.285629
# After 14001 training step(s),loss on training batch is 0.323331
# After 15001 training step(s),loss on training batch is 0.277808
# After 16001 training step(s),loss on training batch is 0.281871
# After 17001 training step(s),loss on training batch is 0.275159
# After 18001 training step(s),loss on training batch is 0.273478
# After 19001 training step(s),loss on training batch is 0.260306
# After 20001 training step(s),loss on training batch is 0.26419
# After 21001 training step(s),loss on training batch is 0.27262
# After 22001 training step(s),loss on training batch is 0.253976
# After 23001 training step(s),loss on training batch is 0.265705
# After 24001 training step(s),loss on training batch is 0.254114
# After 25001 training step(s),loss on training batch is 0.247464
# After 26001 training step(s),loss on training batch is 0.252679
# After 27001 training step(s),loss on training batch is 0.255898
# After 28001 training step(s),loss on training batch is 0.239978
# After 29001 training step(s),loss on training batch is 0.24763
# After 30001 training step(s),loss on training batch is 0.242668
# After 31001 training step(s),loss on training batch is 0.238125
# After 32001 training step(s),loss on training batch is 0.235076
# After 33001 training step(s),loss on training batch is 0.249031
# After 34001 training step(s),loss on training batch is 0.238661
# After 35001 training step(s),loss on training batch is 0.231716
# After 36001 training step(s),loss on training batch is 0.236431
# After 37001 training step(s),loss on training batch is 0.23335
# After 38001 training step(s),loss on training batch is 0.235972
# After 39001 training step(s),loss on training batch is 0.230903
# After 40001 training step(s),loss on training batch is 0.2324
# After 41001 training step(s),loss on training batch is 0.227626
# After 42001 training step(s),loss on training batch is 0.228982
# After 43001 training step(s),loss on training batch is 0.22313
# After 44001 training step(s),loss on training batch is 0.224412
# After 45001 training step(s),loss on training batch is 0.222252
# After 46001 training step(s),loss on training batch is 0.221856
# After 47001 training step(s),loss on training batch is 0.220932
# After 48001 training step(s),loss on training batch is 0.219999
# After 49001 training step(s),loss on training batch is 0.227029

# %%
#conding:utf-8
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import time
# import mnist_forward
# import mnist_backward

TEST_INTERVAL_SECS = 5

def test(mnist):
    with tf.Graph().as_default() as g:
        x = tf.placeholder(tf.float32,[None,INPUT_NODE])
        y_ = tf.placeholder(tf.float32,[None,OUTPUT_NODE])
        y = forward(x,None)
    
        ema = tf.train.ExponentialMovingAverage(MOVING_AVERAGE_DECAY)
        ema_restore = ema.variables_to_restore()
        saver = tf.train.Saver(ema_restore)
        
        correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(y_,1))
        accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
        
        while True:
            with tf.Session() as sess:
                ckpt = tf.train.get_checkpoint_state(MODEL_SAVE_PATH)
                if ckpt and ckpt.model_checkpoint_path:
                    saver.restore(sess,ckpt.model_checkpoint_path)
                    global_step = ckpt.model_checkpoint_path.split('/')[-1].split('-')[-1]
                    accuracy_score = sess.run(accuracy,feed_dict={x:mnist.test.images,y_:mnist.test.labels})
                    print "After %s training step(s),test accuracy = %g" % (global_step,accuracy_score)
                else:
                    print "No checkpoint file found"
                    return
            time.sleep(TEST_INTERVAL_SECS)
            
def main():
    mnist = input_data.read_data_sets("/Users/he/Desktop/hehuanlin/datasets/mnist/data/",one_hot=True)
    test(mnist)
    
if __name__ == '__main__':
    main()
# Out:
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/train-images-idx3-ubyte.gz
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/train-labels-idx1-ubyte.gz
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/t10k-images-idx3-ubyte.gz
# Extracting /Users/he/Desktop/hehuanlin/datasets/mnist/data/t10k-labels-idx1-ubyte.gz
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-750a1d1653e3> in <module>()
#      39
#      40 if __name__ == '__main__':
# ---> 41     main()
#
# <ipython-input-5-750a1d1653e3> in main()
#      36 def main():
#      37     mnist = input_data.read_data_sets("/Users/he/Desktop/hehuanlin/datasets/mnist/data/",one_hot=True)
# ---> 38     test(mnist)
#      39
#      40 if __name__ == '__main__':
#
# <ipython-input-5-750a1d1653e3> in test(mnist)
#      23         while True:
#      24             with tf.Session() as sess:
# ---> 25                 ckpt = tf.train.get_checkpoint_state(mnist_backward.MODEL_SAVE_PATH)
#      26                 if ckpt and ckpt.model_checkpoint_path:
#      27                     saver.restore(sess,ckpt.model_checkpoint_path)
#
# NameError: global name 'mnist_backward' is not defined

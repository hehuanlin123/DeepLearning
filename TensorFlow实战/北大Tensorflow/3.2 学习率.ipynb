# %%
#coding:utf-8
#设损失函数 loss=(w+1)^2，令w初值是常数5。反向传播就是求最优化w，即求最小loss对应的w值
import tensorflow as tf
#定义待优化参数w初值赋5
w = tf.Variable(tf.constant(5,dtype=tf.float32))
#定义损失函数loss
loss = tf.square(w+1)
#定义反向传播方法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
#生成会话，训练40轮
with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    for i in range(40):
        sess.run(train_step)
        w_val = sess.run(w)
        loss_val = sess.run(loss)
        print "After %s steps: w is %f, loss is %f."%(i,w_val,loss_val)
# Out:
# After 0 steps: w is 2.600000, loss is 12.959999.
# After 1 steps: w is 1.160000, loss is 4.665599.
# After 2 steps: w is 0.296000, loss is 1.679616.
# After 3 steps: w is -0.222400, loss is 0.604662.
# After 4 steps: w is -0.533440, loss is 0.217678.
# After 5 steps: w is -0.720064, loss is 0.078364.
# After 6 steps: w is -0.832038, loss is 0.028211.
# After 7 steps: w is -0.899223, loss is 0.010156.
# After 8 steps: w is -0.939534, loss is 0.003656.
# After 9 steps: w is -0.963720, loss is 0.001316.
# After 10 steps: w is -0.978232, loss is 0.000474.
# After 11 steps: w is -0.986939, loss is 0.000171.
# After 12 steps: w is -0.992164, loss is 0.000061.
# After 13 steps: w is -0.995298, loss is 0.000022.
# After 14 steps: w is -0.997179, loss is 0.000008.
# After 15 steps: w is -0.998307, loss is 0.000003.
# After 16 steps: w is -0.998984, loss is 0.000001.
# After 17 steps: w is -0.999391, loss is 0.000000.
# After 18 steps: w is -0.999634, loss is 0.000000.
# After 19 steps: w is -0.999781, loss is 0.000000.
# After 20 steps: w is -0.999868, loss is 0.000000.
# After 21 steps: w is -0.999921, loss is 0.000000.
# After 22 steps: w is -0.999953, loss is 0.000000.
# After 23 steps: w is -0.999972, loss is 0.000000.
# After 24 steps: w is -0.999983, loss is 0.000000.
# After 25 steps: w is -0.999990, loss is 0.000000.
# After 26 steps: w is -0.999994, loss is 0.000000.
# After 27 steps: w is -0.999996, loss is 0.000000.
# After 28 steps: w is -0.999998, loss is 0.000000.
# After 29 steps: w is -0.999999, loss is 0.000000.
# After 30 steps: w is -0.999999, loss is 0.000000.
# After 31 steps: w is -1.000000, loss is 0.000000.
# After 32 steps: w is -1.000000, loss is 0.000000.
# After 33 steps: w is -1.000000, loss is 0.000000.
# After 34 steps: w is -1.000000, loss is 0.000000.
# After 35 steps: w is -1.000000, loss is 0.000000.
# After 36 steps: w is -1.000000, loss is 0.000000.
# After 37 steps: w is -1.000000, loss is 0.000000.
# After 38 steps: w is -1.000000, loss is 0.000000.
# After 39 steps: w is -1.000000, loss is 0.000000.

# %%
#coding:utf-8
#设损失函数 loss=(w+1)^2，令w初值是常数5。反向传播就是求最优化w，即求最小loss对应的w值
#使用指数衰减的学习率，在迭代初期得到较高的下降速度，可以在较小的训练轮数下取得更有收敛度
import tensorflow as tf

LEARNING_RATE_BASE = 0.1 #最初学习率
LEARNING_RATE_DECAY = 0.99 #学习率衰减率
LEARNING_RATE_STEP = 1 #喂入多少轮BATCH_SIZE后，更新一次学习率，一般设为：总样本数/BATCH_SIZE

#运行了几轮BATCH_SIZE的计数器，初值给0，设为不被训练
global_step = tf.Variable(0,trainable=False)

#定义指数下降学习率
learning_rate = tf.train.exponential_decay(LEARNING_RATE_BASE,global_step,LEARNING_RATE_STEP,
                                           LEARNING_RATE_DECAY,staircase=True)
#定义待优化参数w初值赋5
w = tf.Variable(tf.constant(5,dtype=tf.float32))
#定义损失函数loss
loss = tf.square(w+1)
#定义反向传播方法
train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,
                                                                       global_step=global_step)
#生成会话，训练40轮
with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    for i in range(40):
        sess.run(train_step)
        learning_rate_val = sess.run(learning_rate)
        global_step_val = sess.run(global_step)
        w_val = sess.run(w)
        loss_val = sess.run(loss)
        print "After %s steps: global_step is %f, w is %f, learning_rate is %f, loss is %f."%(i,learning_rate_val,global_step_val,w_val,loss_val)
# Out:
# After 0 steps: global_step is 0.099000, w is 1.000000, learning_rate is 3.800000, loss is 23.040001.
# After 1 steps: global_step is 0.098010, w is 2.000000, learning_rate is 2.849600, loss is 14.819419.
# After 2 steps: global_step is 0.097030, w is 3.000000, learning_rate is 2.095001, loss is 9.579033.
# After 3 steps: global_step is 0.096060, w is 4.000000, learning_rate is 1.494386, loss is 6.221961.
# After 4 steps: global_step is 0.095099, w is 5.000000, learning_rate is 1.015167, loss is 4.060896.
# After 5 steps: global_step is 0.094148, w is 6.000000, learning_rate is 0.631886, loss is 2.663051.
# After 6 steps: global_step is 0.093207, w is 7.000000, learning_rate is 0.324608, loss is 1.754587.
# After 7 steps: global_step is 0.092274, w is 8.000000, learning_rate is 0.077684, loss is 1.161403.
# After 8 steps: global_step is 0.091352, w is 9.000000, learning_rate is -0.121202, loss is 0.772287.
# After 9 steps: global_step is 0.090438, w is 10.000000, learning_rate is -0.281761, loss is 0.515867.
# After 10 steps: global_step is 0.089534, w is 11.000000, learning_rate is -0.411674, loss is 0.346128.
# After 11 steps: global_step is 0.088638, w is 12.000000, learning_rate is -0.517024, loss is 0.233266.
# After 12 steps: global_step is 0.087752, w is 13.000000, learning_rate is -0.602644, loss is 0.157891.
# After 13 steps: global_step is 0.086875, w is 14.000000, learning_rate is -0.672382, loss is 0.107334.
# After 14 steps: global_step is 0.086006, w is 15.000000, learning_rate is -0.729305, loss is 0.073276.
# After 15 steps: global_step is 0.085146, w is 16.000000, learning_rate is -0.775868, loss is 0.050235.
# After 16 steps: global_step is 0.084294, w is 17.000000, learning_rate is -0.814036, loss is 0.034583.
# After 17 steps: global_step is 0.083451, w is 18.000000, learning_rate is -0.845387, loss is 0.023905.
# After 18 steps: global_step is 0.082617, w is 19.000000, learning_rate is -0.871193, loss is 0.016591.
# After 19 steps: global_step is 0.081791, w is 20.000000, learning_rate is -0.892476, loss is 0.011561.
# After 20 steps: global_step is 0.080973, w is 21.000000, learning_rate is -0.910065, loss is 0.008088.
# After 21 steps: global_step is 0.080163, w is 22.000000, learning_rate is -0.924629, loss is 0.005681.
# After 22 steps: global_step is 0.079361, w is 23.000000, learning_rate is -0.936713, loss is 0.004005.
# After 23 steps: global_step is 0.078568, w is 24.000000, learning_rate is -0.946758, loss is 0.002835.
# After 24 steps: global_step is 0.077782, w is 25.000000, learning_rate is -0.955125, loss is 0.002014.
# After 25 steps: global_step is 0.077004, w is 26.000000, learning_rate is -0.962106, loss is 0.001436.
# After 26 steps: global_step is 0.076234, w is 27.000000, learning_rate is -0.967942, loss is 0.001028.
# After 27 steps: global_step is 0.075472, w is 28.000000, learning_rate is -0.972830, loss is 0.000738.
# After 28 steps: global_step is 0.074717, w is 29.000000, learning_rate is -0.976931, loss is 0.000532.
# After 29 steps: global_step is 0.073970, w is 30.000000, learning_rate is -0.980378, loss is 0.000385.
# After 30 steps: global_step is 0.073230, w is 31.000000, learning_rate is -0.983281, loss is 0.000280.
# After 31 steps: global_step is 0.072498, w is 32.000000, learning_rate is -0.985730, loss is 0.000204.
# After 32 steps: global_step is 0.071773, w is 33.000000, learning_rate is -0.987799, loss is 0.000149.
# After 33 steps: global_step is 0.071055, w is 34.000000, learning_rate is -0.989550, loss is 0.000109.
# After 34 steps: global_step is 0.070345, w is 35.000000, learning_rate is -0.991035, loss is 0.000080.
# After 35 steps: global_step is 0.069641, w is 36.000000, learning_rate is -0.992297, loss is 0.000059.
# After 36 steps: global_step is 0.068945, w is 37.000000, learning_rate is -0.993369, loss is 0.000044.
# After 37 steps: global_step is 0.068255, w is 38.000000, learning_rate is -0.994284, loss is 0.000033.
# After 38 steps: global_step is 0.067573, w is 39.000000, learning_rate is -0.995064, loss is 0.000024.
# After 39 steps: global_step is 0.066897, w is 40.000000, learning_rate is -0.995731, loss is 0.000018.
